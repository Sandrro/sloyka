# %%
import networkx as nx
import folium
import random
from folium.plugins import MarkerCluster

def visualize_graph(graph_path, zoom: int, terr_loc: list, output_file=None):
    """
    Visualizes a graph from the given graph_path using Folium and MarkerCluster.
    
    Args:
        graph_path (str): The path to the graphml file.
        output_file (str, optional): The file to save the visualization to. Defaults to None.
        
    Returns:
        folium.Map: The folium map object representing the visualized graph.
    """
    G = nx.read_graphml(graph_path)

    m = folium.Map(
        location=terr_loc,
        zoom_start=zoom,
        tiles="cartodb_positron",
        control_scale=True,
    )

    nodes_group = folium.FeatureGroup(name='Nodes')
    neighbors_group = folium.FeatureGroup(name='Neighbors')
    lines_group = folium.FeatureGroup(name='Lines')

    for node, data in G.nodes(data=True):
        if "Lat" in data and "Lon" in data:
            main_node_location = [data["Lon"], data["Lat"]]
            folium.Marker(
                location=main_node_location,
                popup=node,
                icon=folium.DivIcon(
                    icon_size=(60,20),
                    icon_anchor=(0,0),
                    html='<div style="font-size: 12pt; color: blue">%s</div>' % node,
                )
            ).add_to(nodes_group)
            
            for n in G.neighbors(node):
                neighbor_location = [
                    main_node_location[0] + random.uniform(-0.0008, 0.0008),
                    main_node_location[1] + random.uniform(-0.0008, 0.0008),
                ]
                folium.Marker(
                    location=neighbor_location,
                    popup=n,
                    icon=folium.DivIcon(
                        icon_size=(150,50),
                        icon_anchor=(0,0),
                        html=f'<div style="font-size: 10pt;color: darkred">{n}</div>',
                    )
                ).add_to(neighbors_group)
                
                folium.PolyLine([main_node_location, neighbor_location], color="purple", weight=1, opacity=1).add_to(lines_group)

   
    m.add_child(nodes_group)
    m.add_child(neighbors_group)
    m.add_child(lines_group)

    folium.LayerControl().add_to(m)
    if output_file is not None:
        m.save(output_file)
    
    return m

# %%
graph_path='/Users/test/Documents/code/sloyka/sloyka/sample_data/gutcnina.graphml'

# %%
G = nx.read_graphml(graph_path)

# %%
from pprint import pprint
pprint(G.edges(data=True))
# Out:
# OutEdgeDataView([('Гатчинская улица', 'банк', {'distance': 0.7102, 'type': 'содержит'}), ('Гатчинская улица', 'чехов', {'distance': 0.6018, 'type': 'содержит'}), ('Гатчинская улица', 'электричество', {'distance': 0.6161, 'type': 'содержит'}), ('чехов', 'красота', {'distance': 0.756725549697876, 'type': 'сходство'}), ('улица Чкалова 25', 'ремонт', {'distance': 0.6064, 'type': 'содержит'}), ('улица Чкалова', 'водитель', {'distance': 0.627, 'type': 'содержит'}), ('улица Чкалова', 'чкалов', {'distance': 0.8544, 'type': 'содержит'}), ('улица Чкалова', 'приорат', {'distance': 0.8358, 'type': 'содержит'}), ('улица Чкалова', 'россия', {'distance': 0.7032, 'type': 'содержит'}), ('водитель', 'авария', {'distance': 0.7609816193580627, 'type': 'сходство'}), ('улица Крупской', 'авария', {'distance': 0.6237, 'type': 'содержит'}), ('авария', 'водитель', {'distance': 0.7609816193580627, 'type': 'сходство'}), ('переулок Нестерова', 'маскарадный', {'distance': 0.7733, 'type': 'описание'}), ('переулок Нестерова', 'котик', {'distance': 0.7179, 'type': 'содержит'}), ('Павловский мост', 'квартира', {'distance': 0.6269, 'type': 'содержит'}), ('улица Щербакова', 'благодарить', {'distance': 0.8156, 'type': 'активность'}), ('улица Щербакова', 'щербаков', {'distance': 0.636, 'type': 'содержит'}), ('Гатчинское шоссе', 'дорожник', {'distance': 0.6773, 'type': 'содержит'}), ('Ленинградская улица 23ю', 'подсчёт', {'distance': 0.6024, 'type': 'содержит'}), ('Ленинградская улица 23ю', 'бензин', {'distance': 0.6266, 'type': 'содержит'}), ('бензин', 'мебель', {'distance': 0.7643463015556335, 'type': 'сходство'}), ('бензин', 'телефон', {'distance': 0.7652198076248169, 'type': 'сходство'}), ('Балканская площадь д5', 'мебель', {'distance': 0.6536, 'type': 'содержит'}), ('мебель', 'бензин', {'distance': 0.7643463015556335, 'type': 'сходство'}), ('мебель', 'суд', {'distance': 0.7691755890846252, 'type': 'сходство'}), ('набережная канала Грибоедова 4', 'думать', {'distance': 0.6595, 'type': 'активность'}), ('набережная канала Грибоедова 4', 'догадаться', {'distance': 0.6112, 'type': 'активность'}), ('набережная канала Грибоедова 4', 'сам', {'distance': 0.8703, 'type': 'описание'}), ('набережная канала Грибоедова 4', 'почтовый', {'distance': 0.6456, 'type': 'описание'}), ('улица Урицкого', 'телефон', {'distance': 0.6826, 'type': 'содержит'}), ('телефон', 'бензин', {'distance': 0.7652198076248169, 'type': 'сходство'}), ('улица Чехова', 'чехов', {'distance': 0.7512, 'type': 'содержит'}), ('улица Чехова', 'красотища', {'distance': 0.9027, 'type': 'содержит'}), ('Сельская улица', 'электроэнергия', {'distance': 0.7143, 'type': 'содержит'}), ('Ленинградская улица 23', 'красота', {'distance': 0.8312, 'type': 'содержит'}), ('Ленинградская улица 23', 'сияние', {'distance': 0.6903, 'type': 'содержит'}), ('красота', 'забыть', {'distance': 0.7772195935249329, 'type': 'сходство'}), ('красота', 'чехов', {'distance': 0.756725549697876, 'type': 'сходство'}), ('Геологическая улица', 'век', {'distance': 0.8308, 'type': 'содержит'}), ('Геологическая улица', 'килограмм', {'distance': 0.7786, 'type': 'содержит'}), ('Геологическая улица', 'умереть', {'distance': 0.6749, 'type': 'активность'}), ('Геологическая улица', 'суд', {'distance': 0.6426, 'type': 'содержит'}), ('Геологическая улица', 'зверство', {'distance': 0.6533, 'type': 'содержит'}), ('Геологическая улица', 'проплатить', {'distance': 0.6274, 'type': 'активность'}), ('Геологическая улица', 'прочитать', {'distance': 0.7106, 'type': 'активность'}), ('Геологическая улица', 'забыть', {'distance': 0.6624, 'type': 'активность'}), ('Геологическая улица', 'наркосделка', {'distance': 0.6318, 'type': 'содержит'}), ('век', 'средневековье', {'distance': 0.7668315768241882, 'type': 'сходство'}), ('суд', 'мебель', {'distance': 0.7691755890846252, 'type': 'сходство'}), ('забыть', 'красота', {'distance': 0.7772195935249329, 'type': 'сходство'}), ('проспект Авиаконструкторов', 'потерпевший', {'distance': 0.638, 'type': 'описание'}), ('проспект Ави ...

# %%
pprint(G.nodes(data=True))
# Out:
# NodeDataView({'Гатчинская улица': {'tag': 'TOPONYM', 'counts': 2, 'Location': 'Гатчинская улица, Петроградская сторона, Петровский округ, Санкт-Петербург, Северо-Западный федеральный округ, 197136, Россия', 'Lat': 30.2976683, 'Lon': 59.9627854, 'text_ids': '239824,216434'}, 'банк': {'tag': 'NOUN', 'counts': 1}, 'чехов': {'tag': 'NOUN', 'counts': 3}, 'электричество': {'tag': 'NOUN', 'counts': 1}, 'улица Чкалова 25': {'tag': 'TOPONYM', 'counts': 1, 'Location': '25, улица Чкалова, Левашово, Санкт-Петербург, Северо-Западный федеральный округ, 194361, Россия', 'Lat': 30.216043682655503, 'Lon': 60.1006224, 'text_ids': '239533'}, 'ремонт': {'tag': 'NOUN', 'counts': 2}, 'улица Чкалова': {'tag': 'TOPONYM', 'counts': 4, 'Location': 'улица Чкалова, Комарово, Санкт-Петербург, Северо-Западный федеральный округ, 197733, Россия', 'Lat': 29.8146334, 'Lon': 60.1912036, 'text_ids': '239480,239874,221832,200969'}, 'водитель': {'tag': 'NOUN', 'counts': 1}, 'чкалов': {'tag': 'NOUN', 'counts': 1}, 'приорат': {'tag': 'NOUN', 'counts': 1}, 'россия': {'tag': 'NOUN', 'counts': 1}, 'улица Крупской': {'tag': 'TOPONYM', 'counts': 1, 'Location': 'улица Крупской, Смоленское, округ Невская застава, Санкт-Петербург, Северо-Западный федеральный округ, 192148, Россия', 'Lat': 30.4147024, 'Lon': 59.8868979, 'text_ids': '239434'}, 'авария': {'tag': 'NOUN', 'counts': 1}, 'переулок Нестерова': {'tag': 'TOPONYM', 'counts': 1, 'Location': 'переулок Нестерова, Петроградская сторона, Введенский округ, Санкт-Петербург, Северо-Западный федеральный округ, 197198, Россия', 'Lat': 30.2970859, 'Lon': 59.9519121, 'text_ids': '230444'}, 'маскарадный': {'tag': 'ADJF', 'counts': 1}, 'котик': {'tag': 'NOUN', 'counts': 1}, 'Павловский мост': {'tag': 'TOPONYM', 'counts': 1, 'Location': 'Павловский мост, София, Пушкин, Санкт-Петербург, Северо-Западный федеральный округ, 196601, Россия', 'Lat': 30.4086916, 'Lon': 59.7135535, 'text_ids': '230201'}, 'квартира': {'tag': 'NOUN', 'counts': 1}, 'улица Щербакова': {'tag': 'TOPONYM', 'counts': 2, 'Location': 'улица Щербакова, Коломяги, округ Коломяги, Санкт-Петербург, Северо-Западный федеральный округ, 197375, Россия', 'Lat': 30.2988277, 'Lon': 60.0286843, 'text_ids': '230175,229859'}, 'благодарить': {'tag': 'INFN', 'counts': 2}, 'щербаков': {'tag': 'NOUN', 'counts': 1}, 'Гатчинское шоссе': {'tag': 'TOPONYM', 'counts': 1, 'Location': 'Гатчинское шоссе, Дудергоф, Красное Село, Санкт-Петербург, Северо-Западный федеральный округ, 198320, Россия', 'Lat': 30.0998275, 'Lon': 59.7001189, 'text_ids': '221784'}, 'дорожник': {'tag': 'NOUN', 'counts': 1}, 'Ленинградская улица 23ю': {'tag': 'TOPONYM', 'counts': 1, 'Location': 'Ленинградская улица, Торики, округ Горелово, Санкт-Петербург, Северо-Западный федеральный округ, 198323, Россия', 'Lat': 30.1139748, 'Lon': 59.7852698, 'text_ids': '216634'}, 'подсчёт': {'tag': 'NOUN', 'counts': 1}, 'бензин': {'tag': 'NOUN', 'counts': 2}, 'Балканская площадь д5': {'tag': 'TOPONYM', 'counts': 1, 'Location': 'Балканская площадь, Балканский округ, Санкт-Петербург, Северо-Западный федеральный округ, Россия', 'Lat': 30.379063021860834, 'Lon': 59.82974255, 'text_ids': '216631'}, 'мебель': {'tag': 'NOUN', 'counts': 1}, 'набережная канала Грибоедова 4': {'tag': 'TOPONYM', 'counts': 2, 'Location': 'набережная канала Грибоедова, Апраксин двор, округ № 78, Санкт-Петербург, Северо-Западный федеральный округ, 191186, Россия', 'Lat': 30.3261045, 'Lon': 59.9347866, 'text_ids': '216430,187733'}, 'думать': {'tag': 'INFN', 'counts': 1}, 'догадаться': {'tag': 'INFN', 'counts': 1}, 'сам': {'tag': 'ADJF', 'counts': 1}, 'почтовый': {'tag': 'ADJF', 'counts': 1}, 'улица Урицкого': {'tag': 'TOPONYM', 'counts': 1, 'Location': 'улица Урицкого, Зверинец, Павловск, Санкт-Петербург, Северо-Западный федеральный округ, 196621, Россия', 'Lat': 30.473161, 'Lon': 59.6847071, 'text_ids': '210163'}, 'телефон': {'tag': 'NOUN', 'counts': 1}, 'улица Чехова': {'tag': 'TOPONYM', 'counts': 1, 'Location': 'улица Чехова, Нойдорф, Стрельна, Санкт-Петербург, С ...

# %%
zoom = 10   #зум
terr_loc = [60.7076, 28.7528] #позиция карты
visualize_graph(graph_path, zoom, terr_loc, output_file=None)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49f2568c47e8ff42fddfee53acdfffd7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49f2568c47e8ff42fddfee53acdfffd7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49f2568c47e8ff42fddfee53acdfffd7 = L.map(
#                 &quot;map_49f2568c47e8ff42fddfee53acdfffd7&quot;,
#                 {
#                     center: [60.7076, 28.7528],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_49f2568c47e8ff42fddfee53acdfffd7);
#
#
#
#
#
#             var tile_layer_bb74d2c759754363454d15104bd6313e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bb74d2c759754363454d15104bd6313e.addTo(map_49f2568c47e8ff42fddfee53acdfffd7);
#
#
#             var feature_group_1b752042f6d5ada6d5028e851df64bc1 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_860a088b28e8c5464a443b36ae533fce = L.marker(
#                 [59.9627854, 30.2976683],
#                 {}
#             ).addTo(feature_group_1b752042f6d5ada6d5028e851df64bc1);
#
#
#             var div_icon_ca08ffde7c01e37db0d4e47855a93597 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color: blue\&quot;\u003e\u0413\u0430\u0442\u0447\u0438\u043d\u0441\u043a\u0430\u044f \u0443\u043b\u0438\u0446\u0430\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [60, 20]});
#             marker_860a088b28e8c5464a443b36ae533fce.setIcon(div_icon_ca08ffde7c01e37db0d4e47855a93597);
#
#
#         var popup_89cf6f6504df9e90566760c5ffe5443c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c50af0829bb7ff1735622b969ed78ecc = $(`&lt;div id=&quot;html_c50af0829bb7ff1735622b969ed78ecc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Гатчинская улица&lt;/div&gt;`)[0];
#                 popup_89cf6f6504df9e90566760c5ffe5443c.setContent(html_c50af0829bb7ff1735622b969ed78ecc);
#
#
#
#         marker_860a088b28e8c5464a443b36ae533fce.bindPopup(popup_89cf6f6504df9e90566760c5ffe5443c)
#         ;
#
#
#
#
#             var marker_fb007aa8ec4eca1c398ba0e162343df1 = L.marker(
#                 [60.1006224, 30.216043682655503],
#                 {}
#             ).addTo(feature_group_1b752042f6d5ada6d5028e851df64bc1);
#
#
#             var div_icon_b41da393947613770a8455bf7ebb44c5 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color: blue\&quot;\u003e\u0443\u043b\u0438\u0446\u0430 \u0427\u043a\u0430\u043b\u043e\u0432\u0430 25\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [60, 20]});
#             marker_fb007aa8ec4eca1c398ba0e162343df1.setIcon(div_icon_b41da393947613770a8455bf7ebb44c5);
#
#
#         var popup_c2eb6022d0917f2e97d2fdbad153e452 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c9beffccae849dc772790f01369e9c2 = $(`&lt;div id=&quot;html_8c9beffccae849dc772790f01369e9c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;улица Чкалова 25&lt;/div&gt;`)[0];
#                 popup_c2eb6022d0917f2e97d2fdbad153e452.setContent(html_8c9beffccae849dc772790f01369e9c2);
#
#
#
#         marker_fb007aa8ec4eca1c398ba0e162343df1.bindPopup(popup_c2eb6022d0917f2e97d2fdbad153e452)
#         ;
#
#
#
#
#             var marker_f72503d5a14bec7ee500ad007649d37e = L.marker(
#                 [60.1912036, 29.8146334],
#                 {}
#             ).addTo(feature_group_1b752042f6d5ada6d5028e851df64bc1);
#
#
#             var div_icon_17bbabc7f5fe426db07eb4d54da98100 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color: blue\&quot;\u003e\u0443\u043b\u0438\u0446\u0430 \u0427\u043a\u0430\u043b\u043e\u0432\u0430\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [60, 20]});
#             marker_f72503d5a14bec7ee500ad007649d37e.setIcon(div_icon_17bbabc7f5fe426db07eb4d54da98100);
#
#
#         var popup_79836ab8e3a86dad87cb0c4ab8599262 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40d0b7a60ef075c7b1d79b742a4d9aab = $(`&lt;div id=&quot;html_40d0b7a60ef075c7b1d79b742a4d9aab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;улица Чкалова&lt;/div&gt;`)[0];
#                 popup_79836ab8e3a86dad87cb0c4ab8599262.setContent(html_40d0b7a60ef075c7b1d79b742a4d9aab);
#
#
#
#         marker_f72503d5a14bec7ee500ad007649d37e.bindPopup(popup_79836ab8e3a
