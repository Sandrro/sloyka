# %%
import warnings

warnings.simplefilter("ignore")

import os
import sys

folder = os.getcwd().split("\\examples")[0]
sys.path.append(folder)

from sloyka.src.data_getter import VKParser
# Out:
# INFO: Pandarallel will run on -1 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\trolo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
comments_parser = VKParser()

domain = 'shushum' #доменное имя группы
accsess_token=''


result_df = VKParser().run_parser(domain, accsess_token, step=100, cutoff_date='2024-03-20', number_of_messages=10)
# Out:
# 2024-02-05 09:09:00
# posts downloaded
# 100%|██████████| 10/10 [00:16<00:00,  1.69s/it]
# comments downloaded

# %%
result_df
# Out:
#                     date     id  \
# 0    2024-02-05 09:09:00  17563
# 1    2024-04-20 19:53:14  17914
# 2    2024-04-19 10:14:00  17856
# 3    2024-04-18 09:01:44  17834
# 4    2024-04-17 17:42:00  17815
# ..                   ...    ...
# 156  2024-03-06 14:37:48  17742
# 157  2024-03-07 09:05:11  17747
# 158  2024-03-07 09:47:52  17748
# 159  2024-03-08 06:48:49  17749
# 160  2024-03-10 21:34:03  17751
#
#                                                   text  views.count  \
# 0    Безответная Шушарская любовьНе дождавшись [htt...       8034.0
# 1    О строительстве 2-й школы в [club75232234|Пулк...       1078.0
# 2    93-я школа стабильно держит марку - пиарит в о...       6781.0
# 3    Съезд с Московского шоссе на ШкольнуюДирекция ...       3990.0
# 4    Вот и наглядное подтверждение [https://vk.com/...       3087.0
# ..                                                 ...          ...
# 156                              🚩💪⭐ за #Харитонова!✅🌹          NaN
# ...
