# %%
import networkx as nx
from soika.src.hyper_graph.hpgh import make_hyper_graph, draw_hyper_graph
# Out:
# INFO: Pandarallel will run on -1 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
g = nx.read_graphml('/Users/test/Documents/code/soika/soika/sample_data/sample_data_graph.graphml')

# %%
hg = make_hyper_graph(g)

# %%
draw_hyper_graph(hg)
# Out:
# /Users/test/Library/Caches/pypoetry/virtualenvs/soika-hdx_c6ud-py3.11/lib/python3.11/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
