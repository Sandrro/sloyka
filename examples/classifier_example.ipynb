# %%
import torch
import pandas as pd
from factfinder import TextClassifier

# %% [markdown]
# Step 1.
# Enter path to file with texts and number of categories to return

# %%
device_type = torch.device("cuda:0")
path_to_file = "SOIKA/data/raw/Адмиралтейский.csv"

model = TextClassifier(
    repository_id="Sandrro/text_to_function_v2",
    number_of_categories=1,
    device_type=device_type,
)

# %% [markdown]
# Step 2.
# Create DataFrame and make sure that the name of the column with texts is 'Текст' and there are no empty rows

# %%
df_predict = pd.read_csv(path_to_file, sep=";")
df_predict.rename(columns={"Текст комментария": "Текст"}, inplace=True)
df_predict = df_predict.dropna(subset=["Текст"])
df_predict = df_predict.head(100)

# %% [markdown]
# Step 3.
# Start the script and wait! It will return two columns: one with categories ('ЖКХ; Транспорт; Энергетика' or 'ЖКХ', depending on the number of categories) and one with probabilities of these categories

# %%
df_predict[["cats", "probs"]] = pd.DataFrame(
    df_predict["Текст"].progress_map(lambda x: model.run(x)).to_list()
)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 40.23it/s]

# %%
df_predict
# Out:
#     ID автора              Ссылка на автора
# 0   770875820    https://vk.com/id770875820  \
# 1   775009787    https://vk.com/id775009787
# 2   219872867    https://vk.com/id219872867
# 3    42943820     https://vk.com/id42943820
# 4     5079184      https://vk.com/id5079184
# ..        ...                           ...
# 95     580919       https://vk.com/id580919
# 96 -145945152  https://vk.com/club145945152
# 97  323947018    https://vk.com/id323947018
# 98  166194142    https://vk.com/id166194142
# 99   68138653     https://vk.com/id68138653
#
#                      Имя и фамилия автора Пол автора
# 0                        Marina Shaburova          Ж  \
# 1                          Irina Zaytseva          Ж
# 2                         Tatyana Vlasova          Ж
# 3                       Andrey Zagriychuk          М
# 4                         Alexey Akentyev          М
# ..                                    ...        ...
# 95                     Serafima Verkholat          Ж
# ...
