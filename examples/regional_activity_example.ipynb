# %% [markdown]
# Импорт из библиотеки.

# %%
import pandas as pd
import geopandas as gpd

from sloyka.src.risks.regional_activity import RegionalActivity

# %% [markdown]
# Загрузка данных.

# %%
df = pd.read_csv("/sloyka/sloyka/sample_data/tvoygorod34.csv", sep=";")[:20000]

# %% [markdown]
# Инициализация класса

# %%
ra = RegionalActivity(data=df, osm_id=3374767, text_column="text")

# %% [markdown]
# Подсчёт рисков

# %%
res = gpd.GeoDataFrame(ra.get_risks(), geometry="geometry")
