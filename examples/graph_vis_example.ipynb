# %%
import networkx as nx

from soika.src.visual.graph_visualization import visualize_graph
# Out:
# INFO: Pandarallel will run on -1 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
graph_path='/Users/test/Documents/code/soika/soika/sample_data/sample_data_graph.graphml'

# %%
G = nx.read_graphml(graph_path)

# %%
from pprint import pprint
pprint(G.edges(data=True))
# Out:
# OutEdgeDataView([('набережная реки Мойки  Санкт-Петербург Россия', 'консульский', {'distance': 0.6475, 'type': 'описание'}), ('улица Рубинштейна  Санкт-Петербург Россия', 'фасад', {'distance': 0.6336, 'type': 'содержит'}), ('улица Рубинштейна  Санкт-Петербург Россия', 'уборка', {'distance': 0.6262, 'type': 'содержит'}), ('Фурштатская улица  Санкт-Петербург Россия', 'штукатурный', {'distance': 0.8752, 'type': 'описание'}), ('Фурштатская улица  Санкт-Петербург Россия', 'фасад', {'distance': 0.616, 'type': 'содержит'}), ('штукатурный', 'грязный', {'distance': 0.7682531476020813, 'type': 'сходство'}), ('проспект Бакунина  Санкт-Петербург Россия', 'перекупной', {'distance': 0.6095, 'type': 'описание'}), ('Лиговский проспект 44 Санкт-Петербург Россия', 'просить', {'distance': 0.7207, 'type': 'активность'}), ('Коломенская улица  Санкт-Петербург Россия', 'мрак', {'distance': 0.6746, 'type': 'содержит'}), ('Коломенская улица  Санкт-Петербург Россия', 'снег', {'distance': 0.7167, 'type': 'соде
# ...

# %%
pprint(G.nodes(data=True))
# Out:
# NodeDataView({'набережная реки Мойки  Санкт-Петербург Россия': {'tag': 'TOPONYM', 'counts': 1, 'Location': 'набережная реки Мойки, Коломна, округ Коломна, Санкт-Петербург, Северо-Западный федеральный округ, 190121, Россия', 'Lat': 30.2792947, 'Lon': 59.9271166, 'text_ids': '0'}, 'консульский': {'tag': 'ADJF', 'counts': 1}, 'улица Рубинштейна  Санкт-Петербург Россия': {'tag': 'TOPONYM', 'counts': 2, 'Location': 'улица Рубинштейна, Владимирский округ, Санкт-Петербург, Северо-Западный федеральный округ, 191002, Россия', 'Lat': 30.3435599, 'Lon': 59.9282916, 'text_ids': '1,168'}, 'фасад': {'tag': 'NOUN', 'counts': 2}, 'уборка': {'tag': 'NOUN', 'counts': 2}, 'Фурштатская улица  Санкт-Петербург Россия': {'tag': 'TOPONYM', 'counts': 4, 'Location': 'Фурштатская улица, Литейный округ, Санкт-Петербург, Северо-Западный федеральный округ, 191028, Россия', 'Lat': 30.3489868, 'Lon': 59.9453899, 'text_ids': '2,3,4,5'}, 'штукатурный': {'tag': 'ADJF', 'counts': 3}, 'проспект Бакунина  Санкт-Петербург
# ...

# %%
zoom = 10   #зум
visualize_graph(G, zoom)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
