# %%
import warnings
import pandas as pd
warnings.simplefilter("ignore")

import os
import sys

folder = os.getcwd().split("\\examples")[0]
sys.path.append(folder)

from sloyka.src.data_getter import VKParser
from sloyka.src.area_matcher import AreaMatcher
# Out:
# INFO: Pandarallel will run on -1 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\trolo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
comments_parser = VKParser()

domain = 'pkio_klp' #доменное имя группы
accsess_token='...'


df_groups = VKParser().run_parser(domain, accsess_token, step=100, cutoff_date='2024-03-20', number_of_messages=10)
# Out:
# 2024-05-09 14:31:35
# 100%|██████████| 9/9 [00:06<00:00,  1.49it/s]
# comments downloaded

# %%
osm_id = 337422
area_matcher = AreaMatcher()
df_groups['territory'] = df_groups['group_name'].apply(lambda x: area_matcher.match_area(x, osm_id))

# %%
df_groups
# Out:
#                    date    id  \
# 0   2024-05-15 09:19:00  3560
# 1   2024-05-14 19:01:23  3559
# 2   2024-05-14 14:05:01  3558
# 3   2024-05-14 09:51:50  3555
# 4   2024-05-13 12:13:47  3549
# 5   2024-05-11 16:48:00  3538
# 6   2024-05-09 18:41:00  3531
# 7   2024-05-09 15:02:25  3530
# 8   2024-05-09 14:31:35  3529
# 9   2024-05-10 07:56:57  3534
# 10  2024-05-10 11:59:17  3535
# 11  2024-05-11 12:01:53  3536
# 12  2024-05-11 15:38:15  3540
# 13  2024-05-12 14:38:13  3545
# 14  2024-05-12 15:27:04  3546
# 15  2024-05-13 08:01:33  3547
# 16  2024-05-13 08:03:24  3548
# 17  2024-05-14 10:29:01  3557
# 18  2024-05-11 13:11:40  3537
# 19  2024-05-11 13:53:24  3539
# 20  2024-05-11 19:10:21  3541
# 21  2024-05-11 19:18:15  3542
# 22  2024-05-12 10:04:40  3543
# 23  2024-05-12 14:35:21  3544
# 24  2024-05-13 14:21:36  3552
# 25  2024-05-09 16:31:39  3533
#
#                                                  text  views.count  \
# ...
