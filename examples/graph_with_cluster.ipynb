# %%
import pandas as pd
import geopandas as gpd
from pathlib import Path
import networkx as nx

from sloyka.src.semantic_graph.semantic_graph_builder import Semgraph
# Out:
# INFO: Pandarallel will run on -1 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# [nltk_data] Downloading package stopwords to /Users/test/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/test/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-06-13 23:45:31,175 SequenceTagger predicts: Dictionary with 7 tags: O, S-Service, B-Service, E-Service, I-Service, <START>, <STOP>

# %%
sm = Semgraph(device='mps')
# Out:
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
G = sm.build_semantic_graph(gdf,
                            'text',
                            'only_full_street_name',
                            'initial_street',
                            'Toponims',
                            'Location',
                            'geometry',
                            key_score_filter=0.57,
                            semantic_score_filter=0.75)
# Out:
# Clustering data...
#   0%|          | 0/376 [00:00<?, ?it/s]No sentence-transformers model found with name DeepPavlov/rubert-base-cased. Creating a new one with MEAN pooling.
# 100%|██████████| 376/376 [08:45<00:00,  1.40s/it]
# Extracting keywords
# 100%|██████████| 621/621 [06:38<00:00,  1.56it/s]
# Calculating semantic closeness
# 100%|██████████| 113050/113050 [29:28<00:00, 63.93it/s]

# %%
G.nodes['улица Героев']
# Out:
# {'tag': 'TOPONIM',
#  'Location': 'проспект Героев, Южно-Приморский округ, Санкт-Петербург, Северо-Западный федеральный округ, 198335, Россия',
#  'Lat': 30.1647577,
#  'Lon': 59.864655}

# %%
nx.write_graphml(G, 'vuborg_and_co_graph_0.03.graphml', encoding='utf-8')

# %%
from pyvis.network import Network

nt = Network('1000px', '1000px')
nt.show_buttons(filter_=['physics'])
nt.from_nx(G)

nt.write_html('vuborg_and_co_graph.html')

# %%
list(G.nodes)
# Out:
# ['улица Димитрова',
#  'затопить',
#  'макароны',
#  'водяной',
#  'выставка',
#  'галерея',
#  'выставочный',
#  'художница',
#  'Дачная улица',
#  'собака',
#  'улица Лебедева',
#  'лесопосадка',
#  'Псковская улица',
#  'пехота',
#  'десантник',
#  'полка',
#  'батальон',
#  'боевик',
#  'Петровский переулок',
#  'пёс',
#  'Центральная улица',
#  'путин',
#  'россия',
#  'улица Коробицына',
#  'светогорск',
#  'конкурс',
#  'ленинградский',
#  'Каменный проспект',
#  'проголосовать',
#  'голосование',
#  'избиратель',
#  'бюллетень',
#  'Крепостной переулок',
#  'улица',
#  'пешеходный',
#  'московский',
#  'перекрёсток',
#  'Садовая улица',
#  'радовать',
#  'порадовать',
#  'являться',
#  'Суворовский проспект',
#  'вакцинация',
#  'Уральская улица',
#  'новобрачный',
#  'брак',
#  'улица Пушкина',
#  'фестиваль',
#  'мероприятие',
#  'соревнование',
#  'чемпионат',
#  'Павловский проспект',
#  'мост',
#  'путепровод Нева',
#  'подарок',
#  'Горская улица',
#  'облачность',
#  'атмосферный',
#  'набережная Кутузова',
#  'российский',
#  'тюльпан',
#  'букет',
#  'Малиновская улица',
#  'светильник',
#  'Майская улица',
#  'жильё',
#  'квартира',
#  'жилищный',
#  'Школьный переулок',
#  'здравоохранение',
#  'пациент',
#  'медицинский',
#  'Кузьминское шоссе',
#  'беременный',
#  'Советский бульвар',
#  'дзюдо',
#  'фильм',
#  'военный',
#  'всероссийский',
#  'Аэродромная улица',
#  'финляндия',
#  'Вересковая улица',
#  'Павловское шоссе',
#  'Первомайская улица',
#  'импровизация',
#  'Зеленогорское шоссе',
#  'поэт',
#  'Офицерская улица',
#  'зафиксировать',
#  'сообщаться',
#  'вестись',
#  'обращаться',
#  'выступить',
#  'Приморская улица',
#  'женщина',
#  'женский',
#  'жена',
#  'тротуар',
#  'снежный',
#  'проспект',
#  'погодный',
#  'снег',
#  'шторм',
#  'улица Свердлова',
#  'преподаватель',
#  'учитель',
#  'воспитание',
#  'образование',
#  'школа',
#  'набережная реки Сестры',
#  'русский',
#  'Транспортная улица',
#  'водыгубернатор',
#  'Петровская площадь',
#  'дорожный',
#  'транспортный',
#  'водитель',
#  'депутат',
#  'площадь Культуры',
#  'выборы',
#  'голосовать',
#  'Школьная улица',
#  'отреставрировать',
#  'улица Суворова',
#  'дзюдоист',
#  'улица Некрасова',
#  'кот',
#  'котик',
#  'россиянин',
#  'Привокзальная улица',
#  'доброволец',
#  'волонтёр',
#  'улица Володарского',
#  'благотворительный',
#  'Швейцарская улица',
#  'овчарка',
#  'убежать',
#  'Лазаревский переулок',
#  'Выборгский переулок',
#  'музей',
#  'музейный',
#  'архив',
#  'сквер',
#  'площадь',
#  'посёлок',
#  'двор',
#  'Центральная аллея',
#  'вертолёт',
#  'Выборгская улица',
#  'нарушитель',
#  'пенсионер',
#  'уголовный',
#  'грибник',
#  'гриб',
#  'Железнодорожный переулок',
#  'Черноморский переулок',
#  'поезд',
#  'Московский переулок',
#  'улица Сикейроса',
#  'советский',
#  'Петровская улица',
#  'экспонироваться',
#  'Северная площадь',
#  'Ростовская улица',
#  'православный',
#  'Берёзовая улица',
#  'рыбоперерабатывающий',
#  'флот',
#  'судостроительный',
#  'Первомайский проспект',
#  'сельхозтоваропроизводитель',
#  'сельский',
#  'крестьянин',
#  'агропромышленный',
#  'Молодёжное шоссе',
#  'экспозиция',
#  'Вокзальная улица',
#  'подарочный',
#  'Большой проспект',
#  'палатка',
#  'Кленовая улица',
#  'ярмарка',
#  'площадь Европы',
#  'рождественский',
#  'рождество',
#  'праздник',
#  'новогодний',
#  'Финский переулок',
#  'Комсомольская улица',
#  'взрывной',
#  'взрыв',
#  'бульвар Дружбы',
#  'публиковать',
#  'новгород',
#  'проспект Калинина',
#  'комплимент',
#  'Планерная улица',
#  'работодатель',
#  'Пограничная улица',
#  'дождь',
#  'Новосибирская улица',
#  'заболеваемость',
#  'Травяная улица',
#  'вандализм',
#  'граффитчик',
#  'граффити',
#  'улица Антонова-Овсеенко',
#  'магазин',
#  'Гатчинское шоссе',
#  'погода',
#  'день',
#  'Ленинградское шоссе',
#  'госуслуга',
#  'февраль',
#  'март',
#  'Светогорская улица',
#  'волейбол',
#  'Кленовая аллея',
#  'бригада',
#  'Клубная улица',
#  'собеседник',
#  'красавец',
#  'парень',
#  'близкий',
#  'Набережная улица',
#  'беременность',
#  'беременная',
#  'площадь Мужества',
#  'общероссийский',
#  'Северный мост',
#  'избирательный',
#  'Путейская улица',
#  'пожар',
#  'пламя',
#  'сгореть',
#  'пожарный',
#  'Казанский мост',
#  'реставрация',
#  'восстановление',
#  'Захаров переулок',
#  'поздравительный',
#  'поздравить',
#  'зеленогорск',
#  'переулок Газа',
#  'тариф',
#  'проспект Ленина',
#  'пескоуловитель',
#  'водоканал',
#  'морской',
#  'вокзал',
#  'Певческий переулок',
#  'хоровой',
#  'концерт',
#  'Пионерская улица',
#  'весна',
#  'представитель',
#  'таможенный',
#  'улица Ленина',
#  'преступный',
#  'проспект Пятилеток',
#  'декабрь',
#  'январь',
#  'улица Куйбышева',
#  'кутузов',
#  'улица Каменка',
#  'прихожанин',
#  'Пулковская улица',
#  'Потёмкинская улица',
#  'гуманитарный',
#  'Морская улица',
#  'канализационный',
#  'канализациибольша',
#  'канализация',
#  'Красная улица',
#  'издевательство',
#  'улица Смольного',
#  'охотничий',
#  'охота',
#  'охотник',
#  'Саратовская улица',
#  'железнодорожный',
#  'Красноармейская улица',
#  'ресторанчик',
#  'sushipandavyborgс',
#  'ресторан',
#  'Рубежная улица',
#  'юбилей',
#  'компенсация',
#  'компенсациюнаблюдательный',
#  'выплата',
#  'Ириновский проспект',
#  'градостроительство',
#  'Александровский бульвар',
#  'товарыпогулять',
#  'Колтушский мост',
#  'здание',
#  'Тупиковая улица',
#  'туризм',
#  'Новгородская улица',
#  'виртуальный',
#  'Кузнечная улица',
#  'обвинительный',
#  'проспект Энергетиков',
#  'предпринимательство',
#  'предпринимательский',
#  'предприниматель',
#  'Никольская площадь',
#  'поздравлять',
#  'моряк',
#  'Приозерское шоссе',
#  'рождаемость',
#  'Октябрьская улица',
#  'дорожник',
#  'автодорога',
#  'дорога',
#  'пугачёвский',
#  'Московский проспект',
#  'труп',
#  'Цимлянский переулок',
#  'вино',
#  'винодельческий',
#  'Благодатная улица',
#  'плазменный',
#  'плазма',
#  'Приморский переулок',
#  'земляк',
#  'врач',
#  'доктор',
#  'педиатр',
#  'корреспондент',
#  'мостовый',
#  'Железнодорожная улица',
#  'Театральная улица',
#  'Спортивная улица',
#  'пирог',
#  'Советская улица',
#  'фейерверк',
#  'переулок Володарского',
#  'улица Васильева',
#  'анимационный',
#  'Заречная улица',
#  'Выборгское шоссе',
#  'водоснабжение',
#  'водоочистный',
#  'площадь Победы',
#  'аварийный',
#  'авария',
#  'Карельский мост',
#  'реестр',
#  'клиентоориентированность',
#  'Гвардейская улица']

# %%
import networkx as nx

G = nx.read_graphml('/Users/test/Documents/code/sloyka/sloyka/sample_data/gutcnina.graphml')

# %%
print(G.nodes(data=True))
# Out:
# [('Гатчинская улица', {'tag': 'TOPONYM', 'counts': 2, 'Location': 'Гатчинская улица, Петроградская сторона, Петровский округ, Санкт-Петербург, Северо-Западный федеральный округ, 197136, Россия', 'Lat': 30.2976683, 'Lon': 59.9627854, 'text_ids': '239824,216434'}), ('банк', {'tag': 'NOUN', 'counts': 1}), ('чехов', {'tag': 'NOUN', 'counts': 3}), ('электричество', {'tag': 'NOUN', 'counts': 1}), ('улица Чкалова 25', {'tag': 'TOPONYM', 'counts': 1, 'Location': '25, улица Чкалова, Левашово, Санкт-Петербург, Северо-Западный федеральный округ, 194361, Россия', 'Lat': 30.216043682655503, 'Lon': 60.1006224, 'text_ids': '239533'}), ('ремонт', {'tag': 'NOUN', 'counts': 2}), ('улица Чкалова', {'tag': 'TOPONYM', 'counts': 4, 'Location': 'улица Чкалова, Комарово, Санкт-Петербург, Северо-Западный федеральный округ, 197733, Россия', 'Lat': 29.8146334, 'Lon': 60.1912036, 'text_ids': '239480,239874,221832,200969'}), ('водитель', {'tag': 'NOUN', 'counts': 1}), ('чкалов', {'tag': 'NOUN', 'counts': 1}), ('приорат', {'tag': 'NOUN', 'counts': 1}), ('россия', {'tag': 'NOUN', 'counts': 1}), ('улица Крупской', {'tag': 'TOPONYM', 'counts': 1, 'Location': 'улица Крупской, Смоленское, округ Невская застава, Санкт-Петербург, Северо-Западный федеральный округ, 192148, Россия', 'Lat': 30.4147024, 'Lon': 59.8868979, 'text_ids': '239434'}), ('авария', {'tag': 'NOUN', 'counts': 1}), ('переулок Нестерова', {'tag': 'TOPONYM', 'counts': 1, 'Location': 'переулок Нестерова, Петроградская сторона, Введенский округ, Санкт-Петербург, Северо-Западный федеральный округ, 197198, Россия', 'Lat': 30.2970859, 'Lon': 59.9519121, 'text_ids': '230444'}), ('маскарадный', {'tag': 'ADJF', 'counts': 1}), ('котик', {'tag': 'NOUN', 'counts': 1}), ('Павловский мост', {'tag': 'TOPONYM', 'counts': 1, 'Location': 'Павловский мост, София, Пушкин, Санкт-Петербург, Северо-Западный федеральный округ, 196601, Россия', 'Lat': 30.4086916, 'Lon': 59.7135535, 'text_ids': '230201'}), ('квартира', {'tag': 'NOUN', 'counts': 1}), ('улица Щербакова', {'tag': 'TOPONYM', 'counts': 2, 'Location': 'улица Щербакова, Коломяги, округ Коломяги, Санкт-Петербург, Северо-Западный федеральный округ, 197375, Россия', 'Lat': 30.2988277, 'Lon': 60.0286843, 'text_ids': '230175,229859'}), ('благодарить', {'tag': 'INFN', 'counts': 2}), ('щербаков', {'tag': 'NOUN', 'counts': 1}), ('Гатчинское шоссе', {'tag': 'TOPONYM', 'counts': 1, 'Location': 'Гатчинское шоссе, Дудергоф, Красное Село, Санкт-Петербург, Северо-Западный федеральный округ, 198320, Россия', 'Lat': 30.0998275, 'Lon': 59.7001189, 'text_ids': '221784'}), ('дорожник', {'tag': 'NOUN', 'counts': 1}), ('Ленинградская улица 23ю', {'tag': 'TOPONYM', 'counts': 1, 'Location': 'Ленинградская улица, Торики, округ Горелово, Санкт-Петербург, Северо-Западный федеральный округ, 198323, Россия', 'Lat': 30.1139748, 'Lon': 59.7852698, 'text_ids': '216634'}), ('подсчёт', {'tag': 'NOUN', 'counts': 1}), ('бензин', {'tag': 'NOUN', 'counts': 2}), ('Балканская площадь д5', {'tag': 'TOPONYM', 'counts': 1, 'Location': 'Балканская площадь, Балканский округ, Санкт-Петербург, Северо-Западный федеральный округ, Россия', 'Lat': 30.379063021860834, 'Lon': 59.82974255, 'text_ids': '216631'}), ('мебель', {'tag': 'NOUN', 'counts': 1}), ('набережная канала Грибоедова 4', {'tag': 'TOPONYM', 'counts': 2, 'Location': 'набережная канала Грибоедова, Апраксин двор, округ № 78, Санкт-Петербург, Северо-Западный федеральный округ, 191186, Россия', 'Lat': 30.3261045, 'Lon': 59.9347866, 'text_ids': '216430,187733'}), ('думать', {'tag': 'INFN', 'counts': 1}), ('догадаться', {'tag': 'INFN', 'counts': 1}), ('сам', {'tag': 'ADJF', 'counts': 1}), ('почтовый', {'tag': 'ADJF', 'counts': 1}), ('улица Урицкого', {'tag': 'TOPONYM', 'counts': 1, 'Location': 'улица Урицкого, Зверинец, Павловск, Санкт-Петербург, Северо-Западный федеральный округ, 196621, Россия', 'Lat': 30.473161, 'Lon': 59.6847071, 'text_ids': '210163'}), ('телефон', {'tag': 'NOUN', 'counts': 1}), ('улица Чехова', {'tag': 'TOPONYM', 'counts': 1, 'Locat ...
